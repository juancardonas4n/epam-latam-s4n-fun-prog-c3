// %% [markdown]
// # Ejercicios con listas
//
// El propósito de este **Notebook** es en primer lugar interactuar con el tipo de dato `Lista`, en segundo lugar construir un conjunto de funciones que pueble su objeto de compañía de forma que podamos apreciar dos patrones comunes a las funciones de listas. ¡Comencemos!
//
// ## Ejercicio 1. Operación `cola`
//
// Implementar la siguiente función:
//
// ```.scala
// def cola[A](lista:Lista[A]):Option[Lista[A]] = ???
// ```
//
// ## Ejercicio 2. Operación `cabeza`
//
// Implementar la siguiente función:
//
// ```.scala
// def cabeza[A](lista:Lista[A]):Option[A] = ???
// ```
//
// ## Ejercicio 3. Función `mult`
//
// Implementar la siguiente función:
//
// ```.scala
// def mult(lista:Lista[Double]):Double = ???
// ```
//
// ## Ejercicio 4. Función `y`
//
// Implementar la siguiente función:
//
// ```.scala
// def y(lista:Lista[Boolean]):Boolean = ???
// ```
//
// ## Ejercicio 5. Función `o`
//
// Implementar la siguiente función:
//
// ```.scala
// def o(lista:Lista[Boolean]):Boolean = ???
// ```
//
// ## Ejercicio 6. Función `max`
//
// Implementar la siguiente función:
//
// ```.scala
// def max(lista:List[Long]):Long = ???
// ```
//
//
// ## Ejercicio 7. Función `min`
//
// Implementar la siguiente función:
//
// ```.scala
// def min(lista:Lista[Int]):Int = ???
// ```
//
// ## Ejercicio 8. Función `incrLista`
//
//
// ## Ejercicio 9.
